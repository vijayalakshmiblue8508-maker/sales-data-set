# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayalakshmiblue8508-maker/sales-data-set/blob/main/sales_data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path="/content/drive/MyDrive/Sales Dataset.csv"

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(file_path)

# %%
data.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   PaymentMode  Order Date   CustomerName     State     City Year-Month
# 0         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2         UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
import pandas as pd


data = {
    "Order_ID": [1001, 1002, 1003, 1004, 1005],
    "Customer_Name": ["Arun", "Priya", "Rahul", "Divya", "Karthik"],
    "Product": ["Laptop", "Mobile", "Tablet", "Headphones", "Smartwatch"],
    "Category": ["Electronics", "Electronics", "Electronics", "Accessories", "Accessories"],
    "Quantity": [2, 3, 1, 4, 2],
    "Price_per_Unit": [50000, 20000, 30000, 2000, 8000],
    "Order_Date": pd.to_datetime(["2026-02-01", "2026-02-03", "2026-02-05", "2026-02-07", "2026-02-10"])
}

df = pd.DataFrame(data)

df["Total_Sales"] = df["Quantity"] * df["Price_per_Unit"]

print(df)
# Out:
#    Order_ID Customer_Name     Product     Category  Quantity  Price_per_Unit  \
# 0      1001          Arun      Laptop  Electronics         2           50000
# 1      1002         Priya      Mobile  Electronics         3           20000
# 2      1003         Rahul      Tablet  Electronics         1           30000
# 3      1004         Divya  Headphones  Accessories         4            2000
# 4      1005       Karthik  Smartwatch  Accessories         2            8000
#
#   Order_Date  Total_Sales
# 0 2026-02-01       100000
# 1 2026-02-03        60000
# 2 2026-02-05        30000
# 3 2026-02-07         8000
# 4 2026-02-10        16000
